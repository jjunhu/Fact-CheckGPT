# %%
import pandas as pd
import spacy
import random
from textblob import TextBlob
from nltk.corpus import wordnet

# %%
df = pd.read_csv("mapped_summaries_l3.csv")

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Initialize the model and tokenizer
model_name = 'minwhoo/bart-base-negative-claim-generation'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
filtered_df = df[df["book_num"] < 5]
filtered_df
# Out:
#      model_size  book_num  summary_sentence_num  \
# 0          175b         0                     0
# 1          175b         0                     1
# 2          175b         0                     2
# 3          175b         0                     3
# 4          175b         0                     4
# ...         ...       ...                   ...
# 8936       175b         4                  1731
# 8937       175b         4                  1732
# 8938       175b         4                  1733
# 8939       175b         4                  1734
# 8940       175b         4                  1735
#
#                                        summary_sentence  \
# 0     Uncle Pros is helping Laurella, his sick niece...
# 1     Laurella explains that her husband, Consadine,...
# 2     Pros takes the cradle outside to get the last ...
# 3     Mavity sends Bud and Mandy Ann to ask her fath...
# 4     Pros finishes repairing the cradle and places ...
# ...                                                 ...
# 8936  Troy then leaves the room, and Bathsheba burst...
# 8937  Once there, she regained consciousness and ask...
# 8938  Tall answered the door and said that Laban was...
# 8939         Boldwood stood in the passage for a moment
# 8940                             Coggan stepped away to
#
#                                              text_chunk
# 0     THE BIRTH OF A WOMAN-CHILD\n\n"Whose cradle's ...
# 1     selfish--said she'd like to know how I was goi...
# 2     rich, broken light from the cavernous fireplac...
# 3     \n"Well, you go ask Pap to look in the green c...
# 4     she wants--ain't ye, Pretty?"\n\nAnd, having m...
# ...                                                 ...
# 8936  tones of wretchedness and coaxing, "I only rep...
# 8937  who were as usual gazed upon by the burghers w...
# 8938  keep a secret, Coggan?"\n\n"You've proved me, ...
# 8939  who were as usual gazed upon by the burghers w...
# 8940  keep a secret, Coggan?"\n\n"You've proved me, ...
#
# [8941 rows x 5 columns]

# %%
import torch
from tqdm import tqdm

# Function to transform a sentence using the model
def transform_sentences(sentences):
    batch = tokenizer(sentences, max_length=1024, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        out = model.generate(batch['input_ids'], num_beams=5)
    return tokenizer.batch_decode(out, skip_special_tokens=True)

# Process sentences in batches
max_tokens = 1024
batch_size = 10 # Adjust this batch size as needed
modified_sentences = []

for start_idx in tqdm(range(0, len(filtered_df), batch_size), total=len(filtered_df)/10, desc="Processing summary claims"):
    batch_sentences = filtered_df['summary_sentence'][start_idx:start_idx + batch_size].tolist()
    modified_sentences.extend(transform_sentences(batch_sentences))

# Add the modified sentences to the dataframe
filtered_df['summary_sentence'] = modified_sentences
# Out:
# Processing summary claims:   0%|          | 0/894.1 [00:00<?, ?it/s]/Users/jonathanhu/anaconda3/envs/Retrieval/lib/python3.12/site-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Processing summary claims: 895it [17:55,  1.20s/it]
# /var/folders/v3/hwmt_9nx6nl41f06plb5szqr0000gn/T/ipykernel_2019/3583550477.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['summary_sentence'] = modified_sentences

# %%
df = filtered_df[filtered_df['summary_sentence'].str.endswith('.')]

# %%
df.to_csv("negative_claims.csv", index=False)

# %%
df
# Out:
#      model_size  book_num  summary_sentence_num  \
# 2          175b         0                     2
# 4          175b         0                     4
# 5          175b         0                     5
# 7          175b         0                     7
# 8          175b         0                     8
# ...         ...       ...                   ...
# 8930       175b         4                  1725
# 8934       175b         4                  1729
# 8936       175b         4                  1731
# 8937       175b         4                  1732
# 8938       175b         4                  1733
#
#                                        summary_sentence  \
# 2     Pros takes the cradle outside to get the first...
# 4     Pros finishes repair the cradle and removes th...
# 5     Laurella decide to name the baby Johnnie, afte...
# 7     Johnnie's mother, Laurella, is absent from the...
# 8     Laurella reluctantly refuses to let Johnnie go...
# ...                                                 ...
# 8930                    Liddy denies that this is true.
# 8934  She stops to rest for a moment, and then start...
# 8936  Troy then stays in the room, and Bathsheba bur...
# 8937  Once there, she regained consciousness and ask...
# 8938  Tall refused to answer the door and said that ...
#
#                                              text_chunk
# 2     rich, broken light from the cavernous fireplac...
# 4     she wants--ain't ye, Pretty?"\n\nAnd, having m...
# 5     hit the name that should 'a' went with the clo...
# 7     walk. Her mother would get up too, and that wa...
# 8     and able."\n\nAnd sighingly--yet light-hearted...
# ...                                                 ...
# 8930  don't care."\n\n"Who are you, then, who can so...
# 8934  \n\nON CASTERBRIDGE HIGHWAY\n\n\nFor a conside...
# 8936  tones of wretchedness and coaxing, "I only rep...
# 8937  who were as usual gazed upon by the burghers w...
# 8938  keep a secret, Coggan?"\n\n"You've proved me, ...
#
# [2593 rows x 5 columns]
